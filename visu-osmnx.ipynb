# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import osmnx

# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('San Francisco, California'))
# Out:
# <img src="data:image/png;base64,..." width="792">
# (<matplotlib.figure.Figure at 0x7f9f295d4390>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9f295d77b8>)
