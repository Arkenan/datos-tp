# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## Cantidad de bicis
#
# Queremos saber cuántas bicicletas hay en función del tiempo. Para eso tenemos:
#
# - en status.csv disponemos de la cantidad de bicicletas disponibles en un minuto dado.
# - en trips.csv tenemos los viajes en todo momento.
#
# Podemos medir, a las 3 am de todos los días (para minimizar ruido) cuántas bicicletas hay. **NOTA** Podemos usar un _daterange para esto_.
#
# ### Análisis previo: a qué horas hay más bicis en viaje?
#
# Para medir esto levantamos trips.csv y analizamos cada media hora cuántos viajes hay. Primero hagámoslo a las 3. Después vemos cómo lo mejoramos para que sea en todos.

# %%
viajes = pd.read_csv("dataset/trip.csv")

# %%
# Veamos qué estilo tiene.
viajes.head(3)
# Out:
#      id  duration       start_date        start_station_name  \
# 0  4576        63  8/29/2013 14:13  South Van Ness at Market
# 1  4607        70  8/29/2013 14:42        San Jose City Hall
# 2  4130        71  8/29/2013 10:16   Mountain View City Hall
#
#    start_station_id         end_date          end_station_name  \
# 0                66  8/29/2013 14:14  South Van Ness at Market
# 1                10  8/29/2013 14:43        San Jose City Hall
# 2                27  8/29/2013 10:17   Mountain View City Hall
#
#    end_station_id  bike_id subscription_type zip_code
# 0              66      520        Subscriber    94127
# 1              10      661        Subscriber    95138
# 2              27       48        Subscriber    97214

# %%
# Y qué tipos.
viajes.dtypes
# Out:
# id                     int64
# duration               int64
# start_date            object
# start_station_name    object
# start_station_id       int64
# end_date              object
# end_station_name      object
# end_station_id         int64
# bike_id                int64
# subscription_type     object
# zip_code              object
# dtype: object

# %% [markdown]
# ### Arreglemos las fechas.
# Esto debería ser cuestión de, al leer, especificar fechas. Por ahí sea importante tener en cuenta que el formato de fecha es mes/dia/año (oh god why).
#
# Se le especifica que infiera los formatos de fecha, lo cual acelera considerablemente el proceso.

# %%
viajes = pd.read_csv("dataset/trip.csv", parse_dates=["start_date", "end_date"], 
                     infer_datetime_format=True)
viajes.dtypes
# Out:
# id                             int64
# duration                       int64
# start_date            datetime64[ns]
# start_station_name            object
# start_station_id               int64
# end_date              datetime64[ns]
# end_station_name              object
# end_station_id                 int64
# bike_id                        int64
# subscription_type             object
# zip_code                      object
# dtype: object

# %%
viajes.end_date.head(3)
# Out:
# 0   2013-08-29 14:14:00
# 1   2013-08-29 14:43:00
# 2   2013-08-29 10:17:00
# Name: end_date, dtype: datetime64[ns]

# %% [markdown]
# Perfecto, las fechas fueron parseadas y comprobamos que se corrigieron al formato japonés.

# %% [markdown]
# ### Cosas que suceden a las 4 de la mañana
# ¿Cómo se filtra una columna por fechas? Nuestra idea es que queden en la columna las cosas que arrancan antes de las 4:00 y terminan después de las 4:00. Tenemos que comparar fechas.

# %%
a = np.datetime64("2013-01-01 09:59:59")
b = np.datetime64("2013-01-01 10:00:00")
c = np.datetime64("2013-01-01 10:00:01")

a < b < c
# Out:
# True

# %% [markdown]
# Tres fechas cualesquiera se pueden comparar desde arriba. Y si solo nos importa el **tiempo/hora** y no **el día** para filtrar?

# %%
a = np.datetime64("2013-01-01 10:00:00")
b = np.datetime64("2013-01-02 10:00:00")

print(a<b)
print(a.tolist().time() < b.tolist().time())
# Out:
# True
# False

# %% [markdown]
# Perfecto. Esto nos sirve para ver si algo está a las 4 de la mañana. Intentamos filtrar por esa condición.

# %%
viajes4am = viajes[(viajes.start_date.dt.hour < 4) & (4 <= (viajes.end_date.dt.hour))]
len(viajes4am)
# Out:
# 289

# %%
viajes4am = viajes4am.reset_index()

# %% [markdown]
# **Problema**: Esas no son todas. Una bicicleta puede haber sido alquilada por 3 días. Podemos hacer algo al estilo map-reduce.
#
# 1. Map: Por cada una se hace una lista con las horas por las que pasa.
# 2. ReduceByKey: Se cuenta la cantidad de apariciones de cada hora.

# %%
# Suma de apariciones de cada hora en las listas.
suma = [0]*24

def horas(viaje):
    # Obtengo la hora más cercana por arriba al inicio.
    startf = viaje.start_date.ceil("H")
    # Hora más cercana por abajo al fin.
    endf = viaje.end_date.floor("H")
    rango = pd.date_range(start=startf, end=endf, freq="H").hour
    # Sumamos 1 a las apariciones de cada hora en el rango.
    for h in rango:
        suma[h]+=1

# %% [markdown]
# Dato interesante: cuando un apply devuelve una serie, se crea una columna por cada elemento, permitiendo labels. Esto puede ser muy util para otros casos. Acá es peligroso porque se genera un dataframe disperso con muchísimas columnas.

# %%
viajes.apply(horas, axis=1);

# %%
suma
# Out:
# [5421,
#  4538,
#  4437,
#  4161,
#  4081,
#  4207,
#  5485,
#  10268,
#  25354,
#  36833,
#  20502,
#  17957,
#  23667,
#  26990,
#  26942,
#  27284,
#  32827,
#  42876,
#  38695,
#  22753,
#  13998,
#  10079,
#  7993,
#  6308]

# %%
suma = [5421,
 4538,
 4437,
 4161,
 4081,
 4207,
 5485,
 10268,
 25354,
 36833,
 20502,
 17957,
 23667,
 26990,
 26942,
 27284,
 32827,
 42876,
 38695,
 22753,
 13998,
 10079,
 7993,
 6308]

# %%
plt.bar(left=[x for x in range(len(suma))], height=suma)
# Out:
# <img src="data:image/png;base64,..." width="957">
# <Container object of 24 artists>

# %%
totalDias = len(viajes.start_date.dt.date.unique())

# %%
cantBicicletasPorHora = [s/totalDias for s in suma]

# %%
plt.figure("Cantidad de bicicletas alquiladas en cada hora")
plt.bar([x for x in range(len(cantBicicletasPorHora))], cantBicicletasPorHora)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Container object of 24 artists>

# %%
sum(cantBicicletasPorHora)
# Out:
# 577.9754433833563

# %% [markdown]
# ### Tiempo máximo de Viaje
#
# Vemos que start_date y end_date son precisas a nivel minutos, duration a nivel segundos.

# %%
viajes[["start_date","end_date","duration"]]
# Out:
#                 start_date            end_date  duration
# 0      2013-08-29 14:13:00 2013-08-29 14:14:00        63
# 1      2013-08-29 14:42:00 2013-08-29 14:43:00        70
# 2      2013-08-29 10:16:00 2013-08-29 10:17:00        71
# 3      2013-08-29 11:29:00 2013-08-29 11:30:00        77
# 4      2013-08-29 12:02:00 2013-08-29 12:04:00        83
# 5      2013-08-29 18:54:00 2013-08-29 18:56:00       103
# 6      2013-08-29 13:25:00 2013-08-29 13:27:00       109
# 7      2013-08-29 14:02:00 2013-08-29 14:04:00       111
# 55127               50      416        Subscriber    94110
# 72159               55      469        Subscriber    94158
# 79739               61      546        Subscriber    94107
# 88852               71      614        Subscriber    94103
# 92925               74      409        Subscriber    94105
# 98183               64      423        Subscriber    94107
# 115725              61      320        Subscriber    94115
# 124134              61      404        Subscriber    94107
# 160540              82      516        Subscriber    94107
# 181744              32      155        Subscriber    94133
# 194364              39      372        Subscriber    94102
# 213972              39      407        Subscriber    94102
# 252114              67      372        Subscriber    94107
# 301480              75      334        Subscriber    94104
# 326026              55      522        Subscriber    94109
# 345157              69      374        Subscriber    94107
# 349254              63      382          Customer    90034
# 354233              69      336        Subscriber    94403
# 380218              64      410        Subscriber    94107
# 385850              49      591        Subscriber    94404
# 406816              74      461        Subscriber    94103
# 411713              63      238        Subscriber    94105
# 413341              50      441          Customer    94546
# 420035              70      546        Subscriber    94133
# 426791              64      602        Subscriber    94702
# 450401              51      585        Subscriber    94103
# 456799              60      496        Subscriber    94521
# 509279              61      498        Subscriber    94403
# 510302              56      672        Subscriber    94402
# 511423              39      532          Customer    92111
# 531011              69      452        Subscriber    94107
# 542394              51      471        Subscriber    95032
# 547555              59      548        Subscriber    94109
# 556034              67      621        Subscriber    94123
# 572681              64      659        Subscriber    94107
# 597389              55      300        Subscriber    94107
# 616421              69      578        Subscriber    94107
# 618094              77      109        Subscriber    94114
# 633879              68      560          Customer      nil
# 640817              72      358        Subscriber    94062
# 666342              72      291        Subscriber    94117

# %%
viajesMasLargos = viajes.sort_values("duration").tail(10)[["start_date","end_date","duration"]]
viajesMasLargos.duration /= (3600*24)
viajesMasLargos
# Out:
#                 start_date            end_date    duration
# 524521 2015-02-08 03:05:00 2015-02-15 17:17:00    7.591887
# 421839 2015-05-20 15:27:00 2015-05-28 14:49:00    7.973368
# 195379 2014-07-13 05:50:00 2014-07-21 12:32:00    8.279387
# 223016 2014-06-13 16:57:00 2014-06-21 23:59:00    8.292593
# 606063 2014-10-30 08:29:00 2014-11-07 15:36:00    8.338588
# 80510  2013-11-30 13:29:00 2013-12-08 22:06:00    8.359213
# 371066 2015-07-10 10:35:00 2015-07-23 13:27:00   13.119676
# 440339 2015-05-02 06:17:00 2015-05-23 16:53:00   21.442014
# 382718 2015-06-28 21:50:00 2015-07-23 15:27:00   24.733796
# 573566 2014-12-06 21:59:00 2015-06-24 20:18:00  199.888889

# %% [markdown]
# ### Zip_codes
# _A ver en otro momento si es necesario_
# Por que el zip code no figura como numérico? vamos a ver casos que no lo sean.

# %%
zip_codes_fallados = viajes.loc[pd.to_numeric(viajes.zip_code, errors="coerce").isnull(), "zip_code"]

# %%
zip_codes_fallados.value_counts()
# Out:
# nil           10682
# 94040-1724      275
# 94103-2585       60
# v6z2x            25
# 94107-3471       10
# 946-2             4
# M4S1P             2
# Name: zip_code, dtype: int64

# %% [markdown]
# Bueno, por ahora no vamos a tocar los zip-codes. No nos sirven. Y son alto bardo. Algunos no están implícitamente, otros no están explícitamente (nil, son muchos) y otros son compuestos.

# %% [markdown]
# ### Cantidad de dias por semana
# Contar la cantidade viernes _distintos_.

# %%
# Total de viajes por día.
viajes["week_day"] = viajes.start_date.dt.weekday_name
agrupadosPorWeekday= viajes.groupby("week_day")
alquileresPorDia = agrupadosPorWeekday.size()
alquileresPorDia
# Out:
# week_day
# Friday       109361
# Monday       115873
# Saturday      44785
# Sunday        38391
# Thursday     119089
# Tuesday      122259
# Wednesday    120201
# dtype: int64

# %%
fechasDistintas = pd.DataFrame({"fecha": viajes.start_date.dt.date, "week_day": viajes.week_day})

# %%
cantDias = fechasDistintas.groupby(["week_day","fecha"]).agg(lambda x:1).reset_index().week_day.value_counts()
cantDias
# Out:
# Friday       105
# Sunday       105
# Thursday     105
# Saturday     105
# Monday       105
# Wednesday    104
# Tuesday      104
# Name: week_day, dtype: int64

# %%
# Ordeno
cantDias = cantDias.sort_index()
cantDias
# Out:
# Friday       105
# Monday       105
# Saturday     105
# Sunday       105
# Thursday     105
# Tuesday      104
# Wednesday    104
# Name: week_day, dtype: int64

# %%
alquilerPromedioPorDia = alquileresPorDia / cantDias
alquilerPromedioPorDia
# Out:
# week_day
# Friday       1041.533333
# Monday       1103.552381
# Saturday      426.523810
# Sunday        365.628571
# Thursday     1134.180952
# Tuesday      1175.567308
# Wednesday    1155.778846
# dtype: float64

# %%
def ordenarIndiceDias(tabla):
    dias = ["Monday", "Tuesday", "Thursday", "Wednesday", "Friday", "Saturday", "Sunday"]
    indexNuevo = pd.Categorical(tabla.index, categories = dias)
    tabla.index = indexNuevo
    tabla.sort_index(inplace = True)

# %%
ordenarIndiceDias(alquilerPromedioPorDia)

# %%
plt.figure("Alquileres promedio por Día")
alquilerPromedioPorDia.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Tipo de suscriptores

# %%
viajes.subscription_type.value_counts()
# Out:
# Subscriber    566746
# Customer      103213
# Name: subscription_type, dtype: int64

# %%
viajes[["subscription_type", "duration"]].groupby("subscription_type").agg([np.mean, np.sum, np.std])
# Out:
#                       duration
#                           mean        sum           std
# subscription_type
# Customer           3951.761329  407873142  56036.489835
# Subscriber          590.048856  334407829   3451.535890

# %% [markdown]
# Raro. Vamos a sacar los outliers

# %% [markdown]
# ## Sin outliers

# %%
viajes[viajes.duration == 60].size
# Out:
# 600

# %%
viajes[(viajes.duration < 180) & (viajes.end_station_id == viajes.start_station_id)].size
# Out:
# 28020

# %%
viajesSinOutliers = viajes[viajes.duration > 60]

# %%
viajes.duration.sort_values().tail(10) /(3600*24)
# En general el máximo es de 7 días, salvo un outlier de 6 meses.
# Out:
# 524521      7.591887
# 421839      7.973368
# 195379      8.279387
# 223016      8.292593
# 606063      8.338588
# 80510       8.359213
# 371066     13.119676
# 440339     21.442014
# 382718     24.733796
# 573566    199.888889
# Name: duration, dtype: float64

# %%
viajesSinOutliers = viajesSinOutliers[viajesSinOutliers.duration/(3600*24)<100]

# %%
viajesSinOutliers[["subscription_type", "duration", "week_day"]].groupby(["subscription_type", "week_day"] ).agg([np.mean, np.std, np.count_nonzero])
# Hacer día de semana y finde, y cantidad.
# Out:
#                                 duration
#                                     mean           std count_nonzero
# subscription_type week_day
# Customer          Friday     3855.559384  17112.205001         14945
#                   Monday     3373.195483  11206.416510         11469
#                   Saturday   4153.865835  13835.581050         22122
#                   Sunday     4341.234469  21624.406836         19687
#                   Thursday   3463.161847  15586.116546         12450
#                   Tuesday    3299.591304  11160.845398         11040
#                   Wednesday  3252.930144  14108.628105         11495
# Subscriber        Friday      610.902361   3674.396141         94409
#                   Monday      576.203303   2000.968515        104391
#                   Saturday    744.983628  12513.546779         22660
#                   Sunday      695.431849   3338.419536         18701
#                   Thursday    572.118946   1909.598387        106628
#                   Tuesday     565.220153   1562.107231        111209
#                   Wednesday   578.019558   2429.135649        108702

# %% [markdown]
# ### Heatmap

# %%
import seaborn as sns
plt.figure("Correlación")
sns.heatmap(viajesSinOutliers.corr().abs())
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
viajesSinOutliers.week_day = pd.Categorical(viajesSinOutliers.week_day)

# %%
viajesSinOutliers["week_day_01"] = viajesSinOutliers.week_day.apply(lambda x: 0 if x == "Saturday" or x == "Sunday" else 1)

# %%
viajesSinOutliers.week_day_01.value_counts()
# Out:
# 1    586738
# 0     83170
# Name: week_day, dtype: int64

# %%
viajesSinOutliers.dtypes
# Out:
# id                             int64
# duration                       int64
# start_date            datetime64[ns]
# start_station_name            object
# start_station_id               int64
# end_date              datetime64[ns]
# end_station_name              object
# end_station_id                 int64
# bike_id                        int64
# subscription_type             object
# zip_code                      object
# week_day                    category
# week_day_01                    int64
# dtype: object

# %%
a = pd.Series([1,2,3,4,5])

# %% [markdown]
# ## Relación entre duración y pares de estaciones

# %%
viajes["week_day_01"] = viajes.week_day.apply(lambda x: 0 if x == "Saturday" or x == "Sunday" else 1)

viajes[["start_station_id", "end_station_id", "duration", "week_day_01"]]\
    .groupby(["start_station_id","end_station_id","week_day_01"])\
    .agg([np.mean, np.std, np.count_nonzero])
# Out:
#                                                   duration                \
#                                                       mean           std
# start_station_id end_station_id week_day_01
# 2                2              0             11253.333333  18477.966644
#                                 1              7589.336207  30311.988840
#                  3              0               860.653846   1490.332229
#                                 1               539.691919    372.726826
#                  4              0               360.000000    206.380792
#                                 1               288.300703    186.481699
#                  5              0               863.700000   1068.294284
#                                 1               578.938412   3976.116530
#                  6              0               728.655172    719.392715
#                                 1               434.578947    500.529011
#                  7              0               557.739496    228.957788
#                                 1               515.467342    150.053831
#                  8              0               752.358974    266.001334
#                                 1               738.365079    595.034631
#                  9              0               914.083333    346.235459
#                                 1              1022.352843   3794.356203
#                  10             0               957.228571    913.723477
#                                 1              1027.805785   4646.657664
#                  11             0              2115.066667   5292.366252
#                                 1               569.627249    229.801761
#                  12             0               751.285714    247.761184
#                                 1              8393.471591  62939.108909
#                  13             0               682.736842    523.077628
#                                 1               658.901042   2269.414751
#                  14             0               749.666667    897.719611
#                                 1               491.038462    460.261098
#                  16             0               841.460000    438.889425
#                                 1               828.994152   1501.365652
#                  28             0             11381.000000     31.112698
#                                 1            226853.000000           NaN
# ...                                                    ...           ...
# 84               3              0              1029.600000   1214.656536
#                                 1               568.242647    400.948496
#                  4              0               844.727273    551.360697
#                                 1               511.500000    165.332997
#                  5              0              6926.000000      4.242641
#                                 1              1409.700000   1805.738756
#                  6              0               456.620690    324.831607
#                                 1               383.530120    279.684724
#                  7              0               691.500000    422.888452
#                                 1               952.300000   1948.165077
#                  8              0               572.800000     84.697698
#                                 1               661.375000    137.476167
#                  9              0               342.125000    129.950126
#                                 1               362.254237    214.675263
#                  10             0              1322.111111   1517.807172
#                                 1               399.300000     70.112687
#                  11             0              1075.714286    445.678986
#                                 1              3056.444444  12284.907145
#                  12             0              3805.000000   7686.994146
#                                 1               567.650000    123.555770
#                  13             0               327.750000     93.894888
#                                 1               669.454545    397.715316
#                  14             0              1149.909091    894.937479
#                                 1               612.380952    210.874483
#                  16             0               855.000000           NaN
#                                 1              1007.750000    197.933280
#                  80             0               652.583333    176.669418
#                                 1               514.780723    502.068064
#                  84             0             10550.768116  21614.725192
#                                 1              3939.200000  10448.175074
#
#
#                                             count_nonzero
# start_station_id end_station_id week_day_01
# 2                2              0                      75
#                                 1                     116
#                  3              0                      52
#                                 1                     396
#                  4              0                      65
#                                 1                    2135
#                  5              0                      10
#                                 1                     617
#                  6              0                      58
#                                 1                    1216
#                  7              0                     119
#                                 1                     888
#                  8              0                      39
#                                 1                     189
#                  9              0                      36
#                                 1                     598
#                  10             0                      35
#                                 1                     484
#                  11             0                      30
#                                 1                     778
#                  12             0                      14
#                                 1                     176
#                  13             0                      19
#                                 1                     576
#                  14             0                       9
#                                 1                      26
#                  16             0                      50
#                                 1                     342
#                  28             0                       2
#                                 1                       1
# ...                                                   ...
# 84               3              0                      25
#                                 1                     136
#                  4              0                      11
#                                 1                      12
#                  5              0                       2
#                                 1                      10
#                  6              0                      58
#                                 1                      83
#                  7              0                      22
#                                 1                      20
#                  8              0                       5
#                                 1                       8
#                  9              0                      40
#                                 1                      59
#                  10             0                       9
#                                 1                      10
#                  11             0                      14
#                                 1                      27
#                  12             0                       7
#                                 1                      40
#                  13             0                       4
#                                 1                      11
#                  14             0                      11
#                                 1                      21
#                  16             0                       1
#                                 1                       4
#                  80             0                      12
#                                 1                     415
#                  84             0                      69
#                                 1                      55
#
# [3394 rows x 3 columns]

# %% [markdown]
# Esto no debería tener sentido:

# %%
viajes["concat"] = viajes.start_station_id + viajes.end_station_id/100.0

# %%
viajes.head(2)[["start_station_id", "end_station_id", "concat"]]
# Out:
#    start_station_id  end_station_id  concat
# 0                66              66   66.66
# 1                10              10   10.10

# %%
viajes.corr().abs()
# Out:
#                         id  duration  start_station_id  end_station_id  \
# id                1.000000  0.003699          0.031920        0.031535
# duration          0.003699  1.000000          0.007839        0.006719
# start_station_id  0.031920  0.007839          1.000000        0.595154
# end_station_id    0.031535  0.006719          0.595154        1.000000
# bike_id           0.032613  0.002303          0.252053        0.252464
# concat            0.032044  0.007859          0.999968        0.601587
#
#                    bike_id    concat
# id                0.032613  0.032044
# duration          0.002303  0.007859
# start_station_id  0.252053  0.999968
# end_station_id    0.252464  0.601587
# bike_id           1.000000  0.253069
# concat            0.253069  1.000000

# %%
sns.heatmap(viajes.corr().abs())
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
viajes[viajes.start_station_id == viajes.end_station_id].duration.apply(lambda x: x/60).hist(bins=range(1,100))
# Out:
# <img src="data:image/png;base64,..." width="957">

# %% [markdown]
# # Distancias

# %%
estaciones = pd.read_csv("dataset/station.csv")

# %%
estaciones.head()
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date
# 0  San Jose          8/6/2013
# 1  San Jose          8/5/2013
# 2  San Jose          8/6/2013
# 3  San Jose          8/5/2013
# 4  San Jose          8/7/2013

# %%
#armo un diccionario de distancias

ids = estaciones.id
stm = estaciones[["id", "lat", "long"]]

distancias = {}
for id1 in ids:
    x = stm.loc[estaciones.id == id1,["lat","long"]].values
    x = (x[0][0],x[0][1])
    for id2 in ids:
        y = stm.loc[estaciones.id == id2,["lat","long"]].values
        y = (y[0][0],y[0][1])
        # Distancia Manhattan
        distancias[(id1,id2)] = abs(y[0]-x[0]) + abs(y[1] - x[1])

# %%
def d(id1,id2):
    return distancias[(id1,id2)]

# %%
#d(viajes.iloc[x].start_station_id, viajes.iloc[x].end_station_id)
viajes["dist"] = viajes.apply(lambda x: d(x.start_station_id, x.end_station_id), axis=1)

# %%
viajes[["dist","duration"]].corr()
# Out:
#               dist  duration
# dist      1.000000  0.004177
# duration  0.004177  1.000000

# %% [markdown]
# Transformación de distancias en grados a metros. Tomo la tierra como esférica (radio constante).

# %%
# Radio de la tierra en KM
from math import pi
from numpy import sin

R = 6378.137
# Conversor de grados a radianes
conv = pi/180

# Conversión a km de toda la columna.
viajes["distkm"] = R*sin(conv*viajes.dist)

# %%
viajes.distkm.describe()
# Out:
# count    669959.000000
# mean          1.878359
# std           1.143861
# min           0.000000
# 25%           1.207816
# 50%           1.803821
# 75%           2.280157
# max         108.320902
# Name: distkm, dtype: float64

# %%
viajes.sort_values("distkm", ascending = False).head(5)
# Out:
#             id  duration          start_date       start_station_name  \
# 70821    98343     12088 2013-11-16 10:46:00    San Jose Civic Center
# 110007  152848     80183 2014-01-14 12:23:00  San Francisco City Hall
# 102238  141916      7798 2014-01-03 16:41:00     Paseo de San Antonio
# 102453  142229     66748 2014-01-03 20:32:00            Market at 4th
# 481332  695326     29942 2015-03-24 13:04:00              MLK Library
#
#         start_station_id            end_date  \
# 70821                  3 2013-11-16 14:07:00
# 110007                58 2014-01-15 10:39:00
# 102238                 7 2014-01-03 18:51:00
# 102453                76 2014-01-04 15:04:00
# 481332                11 2015-03-24 21:23:00
#
#                          end_station_name  end_station_id  bike_id  \
# 70821   Civic Center BART (7th at Market)              72       30
# 110007                 San Jose City Hall              10      487
# 102238                      Market at 4th              76      164
# 102453               Paseo de San Antonio               7      477
# 481332                      Market at 4th              76      119
#
#        subscription_type zip_code      dist      distkm
# 70821           Customer    95113  0.973110  108.320902
# 110007          Customer    66044  0.972499  108.252895
# 102238          Customer    95112  0.970530  108.033739
# 102453          Customer    95112  0.970530  108.033739
# 481332          Customer    94546  0.969726  107.944251

# %%
estaciones[estaciones.id==3]
# Out:
#    id                   name        lat        long  dock_count      city  \
# 1   3  San Jose Civic Center  37.330698 -121.888979          15  San Jose
#
#   installation_date
# 1          8/5/2013

# %%
estaciones[estaciones.id==72]
# Out:
#     id                               name        lat        long  dock_count  \
# 60  72  Civic Center BART (7th at Market)  37.781039 -122.411748          23
#
#              city installation_date
# 60  San Francisco         8/23/2013

# %%
viajes[["dist","duration"]].plot.scatter(x="dist",y="duration")
# Out:
# <img src="data:image/png;base64,..." width="811">

# %%
viajesSinOutliers[["dist","duration"]].plot.scatter(x="dist",y="duration")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
viajesSinOutliers[["dist","duration"]].corr().abs()
# Out:
#               dist  duration
# dist      1.000000  0.007325
# duration  0.007325  1.000000

# %%
viajesCortos = viajes[viajes.duration < viajes.duration.quantile(0.9)]

# %%
viajes.duration.quantile(0.9)
# Out:
# 1153.0

# %%
viajesCortos.duration.describe()
# Out:
# count    602877.000000
# mean        512.561999
# std         234.405365
# min          60.000000
# 25%         327.000000
# 50%         480.000000
# 75%         667.000000
# max        1152.000000
# Name: duration, dtype: float64

# %%
viajesCortos[["dist","duration"]].plot.scatter(x="dist",y="duration", alpha=0.05);
plt.title("Duración según distancias")
plt.xlim([0,0.1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="881">

# %%
viajesCortos[["dist","duration"]].corr()
# Out:
#               dist  duration
# dist      1.000000  0.648857
# duration  0.648857  1.000000

# %%
viajes.groupby("dist").size().sort_values(ascending=False)
# Out:
# dist
# 0.000000    23981
# 0.012789     9711
# 0.018409     9395
# 0.018781     9196
# 0.019431     7385
# 0.013016     7361
# 0.015439     7054
# 0.013756     7036
# 0.019073     6998
# 0.017759     6780
# 0.019832     6655
# 0.018348     6343
# 0.020234     6292
# 0.019012     5370
# 0.010323     5067
# 0.018559     5006
# 0.022127     4769
# 0.014809     4737
# 0.022105     4601
# 0.013209     4562
# 0.011136     4483
# 0.021934     4313
# 0.014015     4191
# 0.019394     3948
# 0.016204     3819
# 0.018366     3784
# 0.017782     3732
# 0.015002     3573
# 0.009658     3434
# 0.015331     3316
#             ...
# 0.599990        1
# 0.608416        1
# 0.617450        1
# 0.658179        1
# 0.478987        1
# 0.663096        1
# 0.683523        1
# 0.684006        1
# 0.700806        1
# 0.940363        1
# 0.942987        1
# 0.499870        1
# 0.474620        1
# 0.227614        1
# 0.274702        1
# 0.241833        1
# 0.969726        1
# 0.972499        1
# 0.242009        1
# 0.247096        1
# 0.267803        1
# 0.294021        1
# 0.468712        1
# 0.297702        1
# 0.313553        1
# 0.376588        1
# 0.452647        1
# 0.457598        1
# 0.461834        1
# 0.973110        1
# dtype: int64

# %% [markdown]
# **OJO** Hay muchas distancias que solo aparecen una vez.

# %%
plt.figure("frec distancias")
viajes.groupby("dist").size().sort_index().plot();
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure("Histograma de frecuencias de Distancias Recorridas")
viajes.dist.hist(bins=np.arange(0.0, 0.05, 0.001))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Tarea:
# Pasarlo a metros, para algo más entendible
